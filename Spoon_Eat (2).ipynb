# %% [markdown]
# <div style="text-align: center">
# <h1 style="font-size: 48px;">Spoon-Eat</h1>
# </div>
# <div style="text-align: center"> <h2>Clustering Analysis<h2>
# </div>

# %% [markdown]
# # Why I´m doing this Project?

# %% [markdown]
# The growing concern for sustainability and environmental responsibility has pushed the food industry to explore new ways of producing and packaging food products. In this context, Ecotrophelia has become an important platform for young entrepreneurs to showcase their innovative ideas for sustainable food products. Our team is proud to present our project for the Ecotrophelia 2023 competition - an eco-friendly edible spoon made using 3D printing technology and Portuguese ingredients.
#
# To create the perfect recipe for our edible spoon, we conducted a thorough analysis of various data points related to the ingredients and some characteristics of the final product. To make sense of the dataset, we employed clustering analysis, a widely used technique in data analysis that groups similar items together. The results of our analysis helped us identify the ideal combination of ingredients to create a delicious, healthy, and sustainable spoon that will not only reduce waste but also add a unique and flavorful experience to the food consumption process.

# %% [markdown]
# # What is Ecotrophelia?

# %% [markdown]
# ![transferir.jpg](attachment:transferir.jpg)

# %% [markdown]
# Ecotrophelia is a European competition for students who develop innovative, sustainable, and eco-friendly food products. It was first launched in France in 2000 and has since expanded to other countries in Europe. The competition challenges students to create new food products that are environmentally sustainable, healthy, and commercially viable. It aims to encourage young people to be more aware of the environmental impact of food production and to promote entrepreneurship in the food industry. The competition provides a platform for students to showcase their innovative ideas and receive recognition for their work.

# %% [markdown]
# # Spoon-Eat

# %% [markdown]
# ![spoon%20eat.png](attachment:spoon%20eat.png)

# %% [markdown]
# Spoon-eat it´s a product develop by me and some frineds of mine. This are cookies shaped like a spoon and they fit in the cookie, utensils and snacks categories. Their main ingredients are chickpea flour, rice flour, chestnut flour and cinnamon. They have the appearance of small brown colored spoons, due to the flours and spices used. These ingredients are what gives Spoon-eat their flavour and texture.
# Spoon-eat are an innovative source of fiber and it can be used in various ways, with whatever you want: jams, yogurt, ice cream, coffee, tea, etc. - the possibilities are endless. They’re made using 3D printers and mainly Portuguese raw materials, some being the byproduct of other industries. They can be stored in cool dry places, their expiration date is estimated to be around 3 months and they’re distributed using the trucks that bring in ra	w materials.

# %% [markdown]
# ![spoon.png](attachment:spoon.png)

# %% [markdown]
# # The DataSet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimpy import skim
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("spoon_eats.xlsx")

# %%
df
# Out:
#      Bolacha ID  Frainha de Grão de Bico  Farinha de trigo  \
# 0        3d (1)                      NaN            25.500
# 1      (2) 2nov                      NaN            12.750
# 2     (4) 2 nov                      NaN            13.500
# 3      (5) 8nov                      NaN            13.500
# 4     (6) 8 nov                      NaN            19.025
# 5     (7) 8 nov                      NaN            16.875
# 6     (8) 9 nov                      NaN            16.875
# 7         Hoja2                      NaN             0.000
# 8    (10) 9 nov                      NaN             0.000
# 9    (11) 9 nov                      NaN             0.000
# 10   (12) 9 nov                      NaN             0.000
# 11   (13) 9 nov                      NaN             0.000
# 12  (14) 15 mov                      NaN             0.000
# 13  (15) 15 nov                      NaN             0.000
# 14  (16) 15 nov                      NaN             0.000
# ...

# %%
df.columns
# Out:
# Index(['Bolacha ID', 'Frainha de Grão de Bico', 'Farinha de trigo',
#        'Farinha de trigo serraceno', 'Farinha de castanha', 'Farinha de arroz',
#        'Farinha de Alfarroba', 'Farinah de maça', 'Manteiga sem sal', 'açúcar',
#        'sal', 'Agua', 'azeite', 'canela', 'goma xanthana', 'fibra de psilio',
#        'inulina', 'fibra citrica', 'carragenato K', 'goma de alfarroba',
#        'goma guar', 'hpmc', 'pshysillium', 'dehydration temp (ºC)',
#        'dehydration (min)', 'baking temp. (ºC)', 'baking (min)',
#        'texture of raw dough', 'Priting', 'Taste', 'Crispiness', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33'],
#       dtype='object')

# %%
df.drop(columns=["Unnamed: 31","Unnamed: 32","Unnamed: 33"],inplace=True)

# %%
df.head()
# Out:
#   Bolacha ID  Frainha de Grão de Bico  Farinha de trigo  \
# 0     3d (1)                      NaN            25.500
# 1   (2) 2nov                      NaN            12.750
# 2  (4) 2 nov                      NaN            13.500
# 3   (5) 8nov                      NaN            13.500
# 4  (6) 8 nov                      NaN            19.025
#
#    Farinha de trigo serraceno  Farinha de castanha  Farinha de arroz  \
# 0                       0.000                14.60             10.30
# 1                      12.750                14.60             10.30
# 2                      13.500                15.35             11.05
# 3                      13.500                15.35             11.05
# 4                      19.025                15.35               NaN
#
#    Farinha de Alfarroba  Farinah de maça  Manteiga sem sal  açúcar  ...  hpmc  \
# 0                   NaN              NaN               0.0     4.3  ...   NaN
# ...

# %%
# Let´s define the column "Bolacha ID" as index
df.rename(columns={"Bolacha ID":"Id"},inplace=True)
df.set_index("Id",inplace=True)
df
# Out:
#              Frainha de Grão de Bico  Farinha de trigo  \
# Id
# 3d (1)                           NaN            25.500
# (2) 2nov                         NaN            12.750
# (4) 2 nov                        NaN            13.500
# (5) 8nov                         NaN            13.500
# (6) 8 nov                        NaN            19.025
# (7) 8 nov                        NaN            16.875
# (8) 9 nov                        NaN            16.875
# Hoja2                            NaN             0.000
# (10) 9 nov                       NaN             0.000
# (11) 9 nov                       NaN             0.000
# (12) 9 nov                       NaN             0.000
# (13) 9 nov                       NaN             0.000
# (14) 15 mov                      NaN             0.000
# (15) 15 nov                      NaN             0.000
# (16) 15 nov                      NaN             0.000
# (17) 17 nov                      NaN             0.000
# ...

# %%
# Let´s rename the "Frainha de Grão de Bico" column
df.rename(columns={"Frainha de Grão de Bico":"Farinha de Grão de Bico"},inplace=True)

# %%
# Let´s rename the "Farinah de maça" column
df.rename(columns={"Farinah de maça":"Farinha de maça"},inplace=True)

# %% [markdown]
# # 1. Data Cleaning

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 34     │ │ float64     │ 22    │                                                          │
# │ │ Number of columns │ 30     │ │ int32       │ 4     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 4     │                                                          │
# ...

# %% [markdown]
# As we can see we have some missing data to deal with.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 3d (1) to 3FG
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Farinha de Grão de Bico     4 non-null      float64
#  1   Farinha de trigo            30 non-null     float64
#  2   Farinha de trigo serraceno  30 non-null     float64
#  3   Farinha de castanha         31 non-null     float64
#  4   Farinha de arroz            33 non-null     float64
#  5   Farinha de Alfarroba        2 non-null      float64
#  6   Farinha de maça             3 non-null      float64
#  7   Manteiga sem sal            25 non-null     float64
#  8   açúcar                      34 non-null     float64
#  9   sal                         34 non-null     float64
#  10  Agua                        33 non-null     float64
#  11  azeite                      34 non-null     float64
#  12  canela                      4 non-null      float64
# ...

# %%
# Let´s change the type of some columns to float
def float(column):
    df[column] = pd.to_numeric(df[column])

# %%
float("Farinha de Grão de Bico")
float("Farinha de trigo")
float("Farinha de trigo serraceno")
float("Farinha de castanha")
float("Farinha de arroz")
float("Farinha de Alfarroba")
float("Farinha de maça")
float("Manteiga sem sal")
float("canela")
float("goma xanthana")
float("fibra de psilio")
float("inulina")
float("fibra citrica")
float("carragenato K")
float("goma de alfarroba")
float("goma guar")
float("hpmc")
float("pshysillium")

# %% [markdown]
# The main reason for the presence of missing values is because each ingredient wasn´t use it in the recipe, so let´s replace the missing values in each ingredient by 0. However in the "Agua" variabel every recipe has water so let´s replcae it by the mean.
# In the case of the variabels "textura da massa crua", "impressão","sabor","crocância" is because it wasn´t possibel to identify the values of each variabel, so let´s replace it by the mode.

# %% [markdown]
# __Data Cleaning__

# %%
df.isnull().sum()
# Out:
# Farinha de Grão de Bico       30
# Farinha de trigo               4
# Farinha de trigo serraceno     4
# Farinha de castanha            3
# Farinha de arroz               1
# Farinha de Alfarroba          32
# Farinha de maça               31
# Manteiga sem sal               9
# açúcar                         0
# sal                            0
# Agua                           1
# azeite                         0
# canela                        30
# goma xanthana                 24
# fibra de psilio               28
# inulina                       31
# fibra citrica                 31
# carragenato K                 33
# goma de alfarroba             33
# goma guar                     29
# hpmc                          25
# pshysillium                   30
# dehydration temp (ºC)          0
# dehydration (min)              0
# baking temp. (ºC)              0
# baking (min)                   0
# texture of raw dough           2
# Priting                        2
# ...

# %%
# Replacing missing values in ingredients by 0
def ing_m(column):
    df[column] = df[column].fillna(0)

# %%
ing_m("Farinha de Grão de Bico")
ing_m("Farinha de trigo")
ing_m("Farinha de trigo serraceno")
ing_m("Farinha de castanha")
ing_m("Farinha de arroz")
ing_m("Farinha de castanha")
ing_m("Farinha de Alfarroba")
ing_m("Farinha de maça")
ing_m("Manteiga sem sal")
ing_m("canela")
ing_m("goma xanthana")
ing_m("fibra de psilio")
ing_m("carragenato K")
ing_m("goma de alfarroba")
ing_m("goma guar")
ing_m("hpmc")
ing_m("pshysillium")
ing_m("inulina")
ing_m("fibra citrica")

# %%
# Replacing missing values in "Agua" by the mean
df["Agua"] = df["Agua"].fillna(df["Agua"].mean())

# %%
# Replace the "Priting","Taste", "crocância" and "textura da massa crua" by each mode
df["Priting"].value_counts()
# Out:
# ma     21
# boa    11
# Name: Priting, dtype: int64

# %%
df["Priting"] = df["Priting"].fillna("ma")

# %%
df["Priting"] = df["Priting"].str.replace("ma","bad")
df["Priting"] = df["Priting"].str.replace("boa","good")

# %%
df["Taste"].value_counts()
# Out:
# agradavel     23
# mau            8
# agaradavel     1
# Name: Taste, dtype: int64

# %%
df["Taste"] = df["Taste"].fillna("agradavel")

# %%
df["Taste"] = df["Taste"].str.replace("agaradavel","agradavel")

# %%
df["Taste"] = df["Taste"].str.replace("agaradavel","good")

# %%
df["Taste"] = df["Taste"].str.replace("mau","not desirable")

# %%
df["Taste"] = df["Taste"].str.replace("agradavel","desirable")

# %%
df["Crispiness"].value_counts()
# Out:
# pouco crocante          25
# crocante                 4
# poucocrocante            1
# crocância intermedia     1
# crocância intermédia     1
# Name: Crispiness, dtype: int64

# %%
df["Crispiness"] = df["Crispiness"].fillna("pouco crocante")

# %%
df["Crispiness"] = df["Crispiness"].str.replace("poucocrocante","pouco crocante")

# %%
df["Crispiness"] = df["Crispiness"].str.replace("crocância intermedia","crocante")

# %%
df["Crispiness"] = df["Crispiness"].str.replace("crocância intermédia","crocante")

# %%
df["Crispiness"] = df["Crispiness"].str.replace("pouco crocante","little crunchy")

# %%
df["Crispiness"] = df["Crispiness"].str.replace("crocante","crunchy")

# %%
df["texture of raw dough"].value_counts()
# Out:
# fluida     23
# boa         6
# viscosa     2
# espessa     1
# Name: texture of raw dough, dtype: int64

# %%
df["texture of raw dough"] = df["texture of raw dough"].fillna("fluida")

# %%
df["texture of raw dough"] = df["texture of raw dough"].str.replace("fluida","fluid")
df["texture of raw dough"] = df["texture of raw dough"].str.replace("boa","good")
df["texture of raw dough"] = df["texture of raw dough"].str.replace("viscosa","viscous")
df["texture of raw dough"] = df["texture of raw dough"].str.replace("espessa","thick")

# %%
df.isnull().sum()
# Out:
# Farinha de Grão de Bico       0
# Farinha de trigo              0
# Farinha de trigo serraceno    0
# Farinha de castanha           0
# Farinha de arroz              0
# Farinha de Alfarroba          0
# Farinha de maça               0
# Manteiga sem sal              0
# açúcar                        0
# sal                           0
# Agua                          0
# azeite                        0
# canela                        0
# goma xanthana                 0
# fibra de psilio               0
# inulina                       0
# fibra citrica                 0
# carragenato K                 0
# goma de alfarroba             0
# goma guar                     0
# hpmc                          0
# pshysillium                   0
# dehydration temp (ºC)         0
# dehydration (min)             0
# baking temp. (ºC)             0
# baking (min)                  0
# texture of raw dough          0
# Priting                       0
# Taste                         0
# ...

# %% [markdown]
# ## 2. Exploratory Analise

# %%
df.head()
# Out:
#            Farinha de Grão de Bico  Farinha de trigo  \
# Id
# 3d (1)                         0.0            25.500
# (2) 2nov                       0.0            12.750
# (4) 2 nov                      0.0            13.500
# (5) 8nov                       0.0            13.500
# (6) 8 nov                      0.0            19.025
#
#            Farinha de trigo serraceno  Farinha de castanha  Farinha de arroz  \
# Id
# 3d (1)                          0.000                14.60             10.30
# (2) 2nov                       12.750                14.60             10.30
# (4) 2 nov                      13.500                15.35             11.05
# (5) 8nov                       13.500                15.35             11.05
# (6) 8 nov                      19.025                15.35              0.00
#
#            Farinha de Alfarroba  Farinha de maça  Manteiga sem sal  açúcar  \
# Id
# 3d (1)                      0.0              0.0               0.0     4.3
# ...

# %% [markdown]
# ## 2.1. Ingredient Quantities Used in Each Recepi

# %% [markdown]
# Let´s analise the distribution and outliers presence.
#
# The minimum, mean and maximum quantities used of each ingredient.

# %% [markdown]
# __Outliers__

# %%
for column in df.columns[0:26]:
    sns.boxplot(df[column])
    plt.title(column)
    plt.show()

# %% [markdown]
# In most off our variabels we have some outliers but this outliers represnt real data and have extreme importance to this analyse. In sum this outliers are legitimate data points that simply fall outside the typical range, removing them could potentially bias the clustering results and remove important information from the dataset.

# %% [markdown]
# __Distribution__

# %%
for column in df.columns[0:26]:
    sns.distplot(df[column])
    plt.title(column)
    plt.show()

# %% [markdown]
# Just the variabels "açúcar","azeite","desidratação (min)" appears to have a normal distribution.
#
# This might have implications in the efficiency of the use of lienar methods to analyse data.
# A normal distribution can be useful for some statistical analyses, such as hypothesis testing and confidence intervals.

# %%
def max_min(column):
    print("The minimum quantity of '{}' used in a recipe was: {:.2f} g/100g product".format(column, df[column].min()))
    print("The average quantity of '{}' used was: {:.2f} g/100g product".format(column, df[column].mean()))
    print("The maximum quantity of '{}' used was: {:.2f} g/100g product".format(column, df[column].max()))

# %% [markdown]
# __MIN, Mean and Max Quantities of Each Ingredient__

# %%
df.columns
# Out:
# Index(['Farinha de Grão de Bico', 'Farinha de trigo',
#        'Farinha de trigo serraceno', 'Farinha de castanha', 'Farinha de arroz',
#        'Farinha de Alfarroba', 'Farinha de maça', 'Manteiga sem sal', 'açúcar',
#        'sal', 'Agua', 'azeite', 'canela', 'goma xanthana', 'fibra de psilio',
#        'inulina', 'fibra citrica', 'carragenato K', 'goma de alfarroba',
#        'goma guar', 'hpmc', 'pshysillium', 'dehydration temp (ºC)',
#        'dehydration (min)', 'baking temp. (ºC)', 'baking (min)',
#        'texture of raw dough', 'Priting', 'Taste', 'Crispiness'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Farinha de Grão de Bico  Farinha de trigo  Farinha de trigo serraceno  \
# count                34.000000         34.000000                   34.000000
# mean                  2.970588          3.471324                    1.728676
# std                   8.299271          7.175487                    4.884763
# min                   0.000000          0.000000                    0.000000
# 25%                   0.000000          0.000000                    0.000000
# 50%                   0.000000          0.000000                    0.000000
# 75%                   0.000000          0.000000                    0.000000
# max                  28.000000         25.500000                   19.025000
#
#        Farinha de castanha  Farinha de arroz  Farinha de Alfarroba  \
# count            34.000000         34.000000             34.000000
# mean             19.411176         17.688971              0.235294
# std               7.788941          4.838702              1.371989
# ...

# %% [markdown]
# _Farinha de Grão de Bico_

# %%
max_min("Farinha de Grão de Bico")
# Out:
# The minimum quantity of 'Farinha de Grão de Bico' used in a recipe was: 0.00 g/100g product
# The average quantity of 'Farinha de Grão de Bico' used was: 2.97 g/100g product
# The maximum quantity of 'Farinha de Grão de Bico' used was: 28.00 g/100g product

# %% [markdown]
# _Farinha de trigo_

# %%
max_min("Farinha de trigo")
# Out:
# The minimum quantity of 'Farinha de trigo' used in a recipe was: 0.00 g/100g product
# The average quantity of 'Farinha de trigo' used was: 3.47 g/100g product
# The maximum quantity of 'Farinha de trigo' used was: 25.50 g/100g product

# %% [markdown]
# _Farinha de trigo serraceno_

# %%
max_min("Farinha de trigo serraceno")
# Out:
# The minimum quantity of 'Farinha de trigo serraceno' used in a recipe was: 0.00 g/100g product
# The average quantity of 'Farinha de trigo serraceno' used was: 1.73 g/100g product
# The maximum quantity of 'Farinha de trigo serraceno' used was: 19.02 g/100g product

# %% [markdown]
# _Farinha de castanha_

# %%
max_min("Farinha de castanha")
# Out:
# The minimum quantity of 'Farinha de castanha' used in a recipe was: 0.00 g/100g product
# The average quantity of 'Farinha de castanha' used was: 19.41 g/100g product
# The maximum quantity of 'Farinha de castanha' used was: 28.33 g/100g product

# %% [markdown]
# _Farinha de arroz_

# %%
max_min("Farinha de arroz")
# Out:
# The minimum quantity of 'Farinha de arroz' used in a recipe was: 0.00 g/100g product
# The average quantity of 'Farinha de arroz' used was: 17.69 g/100g product
# The maximum quantity of 'Farinha de arroz' used was: 24.02 g/100g product

# %% [markdown]
# _Farinha de Alfarroba_

# %%
max_min("Farinha de Alfarroba")
# Out:
# The minimum quantity of 'Farinha de Alfarroba' used in a recipe was: 0.00 g/100g product
# The average quantity of 'Farinha de Alfarroba' used was: 0.24 g/100g product
# The maximum quantity of 'Farinha de Alfarroba' used was: 8.00 g/100g product

# %% [markdown]
# _Farinha de maça_

# %%
max_min("Farinha de maça")
# Out:
# The minimum quantity of 'Farinha de maça' used in a recipe was: 0.00 g/100g product
# The average quantity of 'Farinha de maça' used was: 0.71 g/100g product
# The maximum quantity of 'Farinha de maça' used was: 10.00 g/100g product

# %% [markdown]
# _Manteiga sem sal_

# %%
max_min("Manteiga sem sal")
# Out:
# The minimum quantity of 'Manteiga sem sal' used in a recipe was: 0.00 g/100g product
# The average quantity of 'Manteiga sem sal' used was: 0.00 g/100g product
# The maximum quantity of 'Manteiga sem sal' used was: 0.00 g/100g product

# %% [markdown]
# _açúcar_

# %%
max_min("açúcar")
# Out:
# The minimum quantity of 'açúcar' used in a recipe was: 4.30 g/100g product
# The average quantity of 'açúcar' used was: 7.53 g/100g product
# The maximum quantity of 'açúcar' used was: 11.00 g/100g product

# %% [markdown]
# _sal_

# %%
max_min("sal")
# Out:
# The minimum quantity of 'sal' used in a recipe was: 0.59 g/100g product
# The average quantity of 'sal' used was: 0.70 g/100g product
# The maximum quantity of 'sal' used was: 1.00 g/100g product

# %% [markdown]
# _Agua_

# %%
max_min("Agua")
# Out:
# The minimum quantity of 'Agua' used in a recipe was: 34.00 g/100g product
# The average quantity of 'Agua' used was: 42.46 g/100g product
# The maximum quantity of 'Agua' used was: 73.90 g/100g product

# %% [markdown]
# _azeite_

# %%
max_min("azeite")
# Out:
# The minimum quantity of 'azeite' used in a recipe was: 1.85 g/100g product
# The average quantity of 'azeite' used was: 3.25 g/100g product
# The maximum quantity of 'azeite' used was: 6.90 g/100g product

# %% [markdown]
# _canela_

# %%
max_min("canela")
# Out:
# The minimum quantity of 'canela' used in a recipe was: 0.00 g/100g product
# The average quantity of 'canela' used was: 0.16 g/100g product
# The maximum quantity of 'canela' used was: 1.40 g/100g product

# %% [markdown]
# ## 2.2. Categorical Data

# %%
def categ(data,column):
    # Define a color palette with 6 colors
    colors = sns.color_palette("husl", 6)

    # Create the figure and subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

    # Plot the countplot in the left subplot
    sns.countplot(x=column, data=data, ax=ax1, palette=colors)
    ax1.set_title(column.upper(), fontsize=20, fontweight="bold")
    

    # Plot the pie chart in the right subplot
    wedges, texts, autotexts = ax2.pie(data[column].value_counts(), 
                                       labels=list(data[column].value_counts().index),
                                       autopct='%1.0f%%', 
                                       colors=colors,
                                       wedgeprops={"linewidth": 1, "edgecolor": "white"})
    ax2.axis("equal")
    ax2.legend(wedges, list(df[column].value_counts().index), 
               loc="center right", bbox_to_anchor=(1.2, 0.5))
    ax2.set_title(column.upper(), fontsize=20, fontweight="bold")

    # Set the font size of the pie chart labels
    for text in texts:
        text.set_fontsize(15)
    for autotext in autotexts:
        autotext.set_fontsize(15)
    
    plt.legend(loc="best")

    # Show the plot
    plt.show()

# %% [markdown]
# ### 2.2.1. Texture of raw dough

# %%
categ(df,"texture of raw dough")

# %% [markdown]
# Only 18% of our recipes were found to have a desirable texture, while a majority of 73% exhibited a fluid texture.

# %%
# Mean of each variabel by texture of raw dough
df.groupby("texture of raw dough").mean()
# Out:
#                       Farinha de Grão de Bico  Farinha de trigo  \
# texture of raw dough
# fluid                                1.120000             4.721
# good                                12.166667             0.000
# thick                                0.000000             0.000
# viscous                              0.000000             0.000
#
#                       Farinha de trigo serraceno  Farinha de castanha  \
# texture of raw dough
# fluid                                      2.351              20.6552
# good                                       0.000              12.8000
# thick                                      0.000              20.6000
# viscous                                    0.000              23.1000
#
#                       Farinha de arroz  Farinha de Alfarroba  Farinha de maça  \
# texture of raw dough
# fluid                        16.913000              0.000000             0.56
# ...

# %% [markdown]
# ### 2.2.2. Priting Performance

# %%
categ(df,"Priting")

# %% [markdown]
# Only 32% off our recipes had a good priting performance

# %%
# Mean of each variabel by priting performance
df.groupby("Priting").mean()
# Out:
#          Farinha de Grão de Bico  Farinha de trigo  \
# Priting
# bad                     1.217391          5.131522
# good                    6.636364          0.000000
#
#          Farinha de trigo serraceno  Farinha de castanha  Farinha de arroz  \
# Priting
# bad                        2.555435            20.132826         16.557609
# good                       0.000000            17.902273         20.054545
#
#          Farinha de Alfarroba  Farinha de maça  Manteiga sem sal    açúcar  \
# Priting
# bad                  0.000000         1.043478               0.0  6.941087
# good                 0.727273         0.000000               0.0  8.774545
#
#               sal  ...  fibra citrica  carragenato K  goma de alfarroba  \
# Priting            ...
# bad      0.682174  ...       0.000000       0.015217           0.015217
# good     0.745455  ...       0.018182       0.000000           0.000000
#
#          goma guar      hpmc  pshysillium  dehydration temp (ºC)  \
# Priting
# ...

# %% [markdown]
# ### 2.2.3. Taste

# %%
categ(df,"Taste")

# %% [markdown]
# Most of the recipes (76%) had a desirable taste.

# %% [markdown]
# ### 2.2.4. Crispiness

# %%
categ(df,"Crispiness")

# %% [markdown]
# Only 18 % of our recipes was crunchy

# %% [markdown]
# ## 2.3. Correlation between Variabels

# %% [markdown]
# It indicates the degree to which changes in one variable are associated with changes in another variable. Correlation is often measured by a correlation coefficient, which is a value that ranges between -1 and 1. A positive correlation coefficient means that as one variable increases, the other variable also tends to increase, while a negative correlation coefficient means that as one variable increases, the other variable tends to decrease.

# %% [markdown]
# Scale of Correlation Coeficient:
#
# 0<=r<=0.19---Very Low Correlation
#
# 0.2<=r<=0.59---Low Correlation
#
# 0.4<=r<=0.59 Moderate Correlation
#
# 0.6<=r<=0.79---High Correlation
#
# 0.8<=r<=1.0---Very High Correlation

# %% [markdown]
# ### 2.3.1. Encoding Categorical Variabel

# %% [markdown]
# Encoding a categorical variable means transforming it from its original text or string form to a numerical representation that can be used for analysis and modeling

# %%
df.head()
# Out:
#            Farinha de Grão de Bico  Farinha de trigo  \
# Id
# 3d (1)                         0.0            25.500
# (2) 2nov                       0.0            12.750
# (4) 2 nov                      0.0            13.500
# (5) 8nov                       0.0            13.500
# (6) 8 nov                      0.0            19.025
#
#            Farinha de trigo serraceno  Farinha de castanha  Farinha de arroz  \
# Id
# 3d (1)                          0.000                14.60             10.30
# (2) 2nov                       12.750                14.60             10.30
# (4) 2 nov                      13.500                15.35             11.05
# (5) 8nov                       13.500                15.35             11.05
# (6) 8 nov                      19.025                15.35              0.00
#
#            Farinha de Alfarroba  Farinha de maça  Manteiga sem sal  açúcar  \
# Id
# 3d (1)                      0.0              0.0               0.0     4.3
# ...

# %% [markdown]
# Let´s encode the follow categorical variabels: "texture of raw dough", "Priting","Taste","Crispiness"

# %% [markdown]
# _texture of raw dough_

# %%
df["texture of raw dough"].value_counts()
# Out:
# fluid      25
# good        6
# viscous     2
# thick       1
# Name: texture of raw dough, dtype: int64

# %%
# Define the order of the categories
order = ['fluid', 'viscous',"good","thick"]

# Perform ordinal encoding
df['texture of raw dough'] = df['texture of raw dough'].astype('category').cat.reorder_categories(order, ordered=True).cat.codes

# %%
df["texture of raw dough"].value_counts()
# Out:
# 0    25
# 2     6
# 1     2
# 3     1
# Name: texture of raw dough, dtype: int64

# %% [markdown]
# __Priting__

# %%
df["Priting"].value_counts()
# Out:
# bad     23
# good    11
# Name: Priting, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Priting'] = le.fit_transform(df['Priting'])

# %%
df["Priting"].value_counts()
# Out:
# 0    23
# 1    11
# Name: Priting, dtype: int64

# %% [markdown]
# __Taste__

# %%
df["Taste"].value_counts()
# Out:
# desirable        26
# not desirable     8
# Name: Taste, dtype: int64

# %%
# Define the order of the categories
order = ["not desirable","desirable"]

# Perform ordinal encoding
df['Taste'] = df['Taste'].astype('category').cat.reorder_categories(order, ordered=True).cat.codes

# %%
df["Taste"].value_counts()
# Out:
# 1    26
# 0     8
# Name: Taste, dtype: int64

# %% [markdown]
# __Crispiness__

# %%
df["Crispiness"].value_counts()
# Out:
# little crunchy    28
# crunchy            6
# Name: Crispiness, dtype: int64

# %%
# Define the order of the categories
order = ["little crunchy","crunchy"]

# Perform ordinal encoding
df['Crispiness'] = df['Crispiness'].astype('category').cat.reorder_categories(order, ordered=True).cat.codes

# %%
df["Crispiness"].value_counts()
# Out:
# 0    28
# 1     6
# Name: Crispiness, dtype: int64

# %% [markdown]
# ### 2.3.1. Correlation Analise

# %%
corr=df.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
mask = corr.abs() > 0.6

# plot heatmap with filtered correlations
plt.figure(figsize=(12,10))
sns.heatmap(corr[mask], annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# After analyzing the heatmap, the following conclusions can be drawn regarding the correlations between the variables:
# * The texture of raw dough has a strong positive correlation with crispiness (0.61), dehydration time (min) (0.64), and goma guar (0.61).
# * Printing does not show a strong correlation with any of the variables.
# * Taste has a strong positive correlation with farinha de arroz (0.75), farinha de trigo sarraceno (0.63), and farinha de trigo (0.83).
# * Crispiness has a strong positive correlation with the texture of raw dough (0.61).
#
# However, it's important to note that these conclusions should be taken with caution, as the dataset is small, imbalanced, and many of the variables do not follow a normal distribution. In fact, most of the variables have constant values, which can affect the reliability of the correlations observed. Therefore, these conclusions may not be entirely reliable or generalizable to other contexts.

# %% [markdown]
# # 3. Machine Learning

# %% [markdown]
# In other to find the best recipe let´s do a Cluster analyse. This is a statistical technique used to group a set of objects in such a way that objects in the same group, called a cluster, are more similar to each other than to those in other groups. The goal of cluster analysis is to identify patterns or structure in data that is not immediately apparent.

# %% [markdown]
# ## 3.1. Data Preprocessing

# %%
df1 = df.copy()

# %% [markdown]
# ### 3.1.1. Feature Scaling

# %%
df1.head()
# Out:
#            Farinha de Grão de Bico  Farinha de trigo  \
# Id
# 3d (1)                         0.0            25.500
# (2) 2nov                       0.0            12.750
# (4) 2 nov                      0.0            13.500
# (5) 8nov                       0.0            13.500
# (6) 8 nov                      0.0            19.025
#
#            Farinha de trigo serraceno  Farinha de castanha  Farinha de arroz  \
# Id
# 3d (1)                          0.000                14.60             10.30
# (2) 2nov                       12.750                14.60             10.30
# (4) 2 nov                      13.500                15.35             11.05
# (5) 8nov                       13.500                15.35             11.05
# (6) 8 nov                      19.025                15.35              0.00
#
#            Farinha de Alfarroba  Farinha de maça  Manteiga sem sal  açúcar  \
# Id
# 3d (1)                      0.0              0.0               0.0     4.3
# ...

# %%
df2 = df1.copy()

# %%
df2.describe()
# Out:
#        Farinha de Grão de Bico  Farinha de trigo  Farinha de trigo serraceno  \
# count                34.000000         34.000000                   34.000000
# mean                  2.970588          3.471324                    1.728676
# std                   8.299271          7.175487                    4.884763
# min                   0.000000          0.000000                    0.000000
# 25%                   0.000000          0.000000                    0.000000
# 50%                   0.000000          0.000000                    0.000000
# 75%                   0.000000          0.000000                    0.000000
# max                  28.000000         25.500000                   19.025000
#
#        Farinha de castanha  Farinha de arroz  Farinha de Alfarroba  \
# count            34.000000         34.000000             34.000000
# mean             19.411176         17.688971              0.235294
# std               7.788941          4.838702              1.371989
# ...

# %% [markdown]
# Feature scaling is the process of transforming variables or features of different scales to a standard scale in order to make them comparable. As we see before pour variabels has differents ranges so we need to perform deature scaling in order to reduce all variables to the same range of variation

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
df3=sc.fit_transform(df2)

# %%
df3
# Out:
# array([[-0.3633164 ,  3.11615815, -0.35921352, ..., -0.69156407,
#         -1.80277564, -0.46291005],
#        [-0.3633164 ,  1.31255381,  2.29019626, ..., -0.69156407,
#         -1.80277564, -0.46291005],
#        [-0.3633164 ,  1.41864818,  2.44604389, ..., -0.69156407,
#         -1.80277564, -0.46291005],
#        ...,
#        [ 2.93890596, -0.49105052, -0.35921352, ...,  1.44599761,
#          0.5547002 ,  2.1602469 ],
#        [ 2.3273833 , -0.49105052, -0.35921352, ...,  1.44599761,
#          0.5547002 ,  2.1602469 ],
#        [ 3.06121049, -0.49105052, -0.35921352, ..., -0.69156407,
#          0.5547002 , -0.46291005]])

# %% [markdown]
# ### 3.1.2. PCA

# %% [markdown]
# PCA stands for Principal Component Analysis. It is a dimensionality reduction technique used to transform high-dimensional datasets into a lower-dimensional space. It does so by identifying the principal components in the data, which are new variables that are linear combinations of the original features. These new variables are ordered in terms of how much variance they explain in the data.
#
# Beacause in this case we have a lot of variabels we nee to apply PCA.

# %%
from sklearn.decomposition import PCA

# %%
# Let´s set that we want 95% of variance in our data
pca = PCA(0.95)
df_cluster = df3.copy()
pca_result = pca.fit_transform(df_cluster)

# %%
pca_result.shape
# Out:
# (34, 16)

# %%
df3.shape
# Out:
# (34, 30)

# %%
print ('Cumulative variance explained by 2 principal components: {:.2%}'.format(np.sum(pca.explained_variance_ratio_)))
# Out:
# Cumulative variance explained by 2 principal components: 96.14%

# %%
pca_result = pd.DataFrame(pca_result)
pca_result
# Out:
#           0         1         2         3         4         5         6   \
# 0  -3.423612  3.374440  0.462359  0.111759  0.302031 -0.230308  0.000545
# 1  -3.547341  3.595368  0.565165  0.050561  0.477923 -0.357156 -0.220423
# 2  -4.133365  4.672463  1.158928 -0.128259  1.585538 -1.692631 -2.317610
# 3  -2.847759  2.753922  0.467606  0.037739 -0.263266  0.451628  0.642667
# 4  -3.553835  4.127864  0.960633  0.160888 -0.127346  0.598800  0.868475
# 5  -1.885484  1.544733  0.057947 -0.040252 -0.626852  0.504969  0.696268
# 6  -1.885484  1.544733  0.057947 -0.040252 -0.626852  0.504969  0.696268
# 7  -0.867321 -0.982475 -0.653995 -0.423976 -0.729062  0.206528  0.373452
# 8  -0.786137 -1.229988 -1.530452 -2.166056 -0.868047  0.442321 -0.823775
# 9  -0.733456 -1.173904 -1.635551 -2.050030 -0.752747  0.317237 -0.902531
# 10 -1.069630 -1.261253 -1.945013 -2.219043 -0.795403  0.243006 -1.378877
# 11 -1.069630 -1.261253 -1.945013 -2.219043 -0.795403  0.243006 -1.378877
# ...

# %% [markdown]
# ### 3.1.3. Determine the K

# %%
pca_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       34 non-null     float64
#  1   1       34 non-null     float64
#  2   2       34 non-null     float64
#  3   3       34 non-null     float64
#  4   4       34 non-null     float64
#  5   5       34 non-null     float64
#  6   6       34 non-null     float64
#  7   7       34 non-null     float64
#  8   8       34 non-null     float64
#  9   9       34 non-null     float64
#  10  10      34 non-null     float64
#  11  11      34 non-null     float64
#  12  12      34 non-null     float64
#  13  13      34 non-null     float64
#  14  14      34 non-null     float64
#  15  15      34 non-null     float64
# dtypes: float64(16)
# memory usage: 4.4 KB

# %% [markdown]
# K is the number of clusters

# %% [markdown]
# __Elbow Method__

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1,8):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=7,random_state=0)
    kmeans.fit(pca_result)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,8),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# __Dendogram__

# %%
import scipy.cluster.hierarchy as sch
from matplotlib import pyplot
pyplot.figure(figsize=(12, 5))
dendrogram = sch.dendrogram(sch.linkage(pca_result, method = 'ward'))
plt.title('Dendrogram')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# By the dendogram and the Elbow Method the K appears to be 3

# %% [markdown]
# ### 3.1.4. K-Means Cluster

# %%
df_kmeans = pca_result.copy()

# %%
# Training the K-Mean model
kmeans = KMeans(n_clusters = 3, init = 'k-means++')
y_kmeans = kmeans.fit_predict(df_kmeans)

# %%
df_kmeans
# Out:
#           0         1         2         3         4         5         6   \
# 0  -3.423612  3.374440  0.462359  0.111759  0.302031 -0.230308  0.000545
# 1  -3.547341  3.595368  0.565165  0.050561  0.477923 -0.357156 -0.220423
# 2  -4.133365  4.672463  1.158928 -0.128259  1.585538 -1.692631 -2.317610
# 3  -2.847759  2.753922  0.467606  0.037739 -0.263266  0.451628  0.642667
# 4  -3.553835  4.127864  0.960633  0.160888 -0.127346  0.598800  0.868475
# 5  -1.885484  1.544733  0.057947 -0.040252 -0.626852  0.504969  0.696268
# 6  -1.885484  1.544733  0.057947 -0.040252 -0.626852  0.504969  0.696268
# 7  -0.867321 -0.982475 -0.653995 -0.423976 -0.729062  0.206528  0.373452
# 8  -0.786137 -1.229988 -1.530452 -2.166056 -0.868047  0.442321 -0.823775
# 9  -0.733456 -1.173904 -1.635551 -2.050030 -0.752747  0.317237 -0.902531
# 10 -1.069630 -1.261253 -1.945013 -2.219043 -0.795403  0.243006 -1.378877
# 11 -1.069630 -1.261253 -1.945013 -2.219043 -0.795403  0.243006 -1.378877
# ...

# %%
# We called the df, that's why we need to refer to previous df to add cluster numbers
df_kmeans = df2.copy()
# Checking number of items in clusters and creating 'Cluster' column
df_kmeans['Cluster'] = y_kmeans
df_kmeans['Cluster'].value_counts()
# Out:
# 0    23
# 2     7
# 1     4
# Name: Cluster, dtype: int64

# %%
df_kmeans
# Out:
#              Farinha de Grão de Bico  Farinha de trigo  \
# Id
# 3d (1)                           0.0            25.500
# (2) 2nov                         0.0            12.750
# (4) 2 nov                        0.0            13.500
# (5) 8nov                         0.0            13.500
# (6) 8 nov                        0.0            19.025
# (7) 8 nov                        0.0            16.875
# (8) 9 nov                        0.0            16.875
# Hoja2                            0.0             0.000
# (10) 9 nov                       0.0             0.000
# (11) 9 nov                       0.0             0.000
# (12) 9 nov                       0.0             0.000
# (13) 9 nov                       0.0             0.000
# (14) 15 mov                      0.0             0.000
# (15) 15 nov                      0.0             0.000
# (16) 15 nov                      0.0             0.000
# (17) 17 nov                      0.0             0.000
# ...

# %% [markdown]
# ### 3.1.5. Hierarchical Cluestering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
df_AgglomerativeC = pca_result.copy()

# %%
# Training model
AgglomerativeC = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'ward')
y_AgglomerativeC = AgglomerativeC.fit_predict(df_AgglomerativeC)

# %%
df_AgglomerativeC = df2.copy()
# Checking number of items in clusters and creating 'Cluster' column
df_AgglomerativeC['Cluster'] = y_AgglomerativeC
df_AgglomerativeC['Cluster'].value_counts()
# Out:
# 0    23
# 2     7
# 1     4
# Name: Cluster, dtype: int64

# %%
df_AgglomerativeC
# Out:
#              Farinha de Grão de Bico  Farinha de trigo  \
# Id
# 3d (1)                           0.0            25.500
# (2) 2nov                         0.0            12.750
# (4) 2 nov                        0.0            13.500
# (5) 8nov                         0.0            13.500
# (6) 8 nov                        0.0            19.025
# (7) 8 nov                        0.0            16.875
# (8) 9 nov                        0.0            16.875
# Hoja2                            0.0             0.000
# (10) 9 nov                       0.0             0.000
# (11) 9 nov                       0.0             0.000
# (12) 9 nov                       0.0             0.000
# (13) 9 nov                       0.0             0.000
# (14) 15 mov                      0.0             0.000
# (15) 15 nov                      0.0             0.000
# (16) 15 nov                      0.0             0.000
# (17) 17 nov                      0.0             0.000
# ...

# %% [markdown]
# # 4. Cluster Analyse

# %% [markdown]
# Let´s analyse each cluster in order to find out which cluster has the best quality.

# %% [markdown]
# __Cluster 0__

# %%
cluster_0 = df_AgglomerativeC[df_AgglomerativeC["Cluster"]==0]

# %%
cluster_0.shape
# Out:
# (23, 31)

# %% [markdown]
# We have 23 recipes belonging to the cluster 0. Now let´s analyse this cluster in more detail.

# %% [markdown]
# _Priting Performance_

# %%
categ(cluster_0,"Priting")

# %% [markdown]
# 65% of the recipes belong to the cluster 0 had a bad priting performnace, and only 35% had a good priting performance.

# %% [markdown]
# _Taste_

# %%
categ(cluster_0,"Taste")

# %% [markdown]
# Overall, the taste off the cluster 0 was good, with 96% of the recipes with goofd taste.

# %% [markdown]
# _Crispiness_

# %%
categ(cluster_0,"Crispiness")

# %% [markdown]
# The crispiness off this cluster was bad, where 87% of the recipes had a bad crispiness,

# %% [markdown]
# _Ingredients_

# %%
sns.set(style='white',font_scale=1.3, rc={'figure.figsize':(20,20)})
ax=cluster_0.hist(bins=20,color='red' )

# %% [markdown]
# In the recipes off this cluster we can see that it mainly has "farinha de castanha" and "farinha de arroz".

# %% [markdown]
# Overall: This recipe doesn´t appear to be the best one. It has a good taste but it isn´t crunchy and doesn´t had a good priting performance.

# %% [markdown]
# __Cluster 1__

# %%
cluster_1 = df_AgglomerativeC[df_AgglomerativeC["Cluster"]==1]

# %%
cluster_1.shape
# Out:
# (4, 31)

# %% [markdown]
# We have 4 recipes bellonging to the cluster 1. Now let´s analyse this cluster in more detail.

# %% [markdown]
# _Priting Performance_

# %%
categ(cluster_1,"Priting")

# %% [markdown]
# Overall this cluster appears to have a good priting performance, where 75% off the recipes had a good priting performance, and only 25% had a bad performance. Just one recipe had a bad priting performance.

# %% [markdown]
# _Taste_

# %%
categ(cluster_1,"Taste")

# %% [markdown]
# Every recipe off this cluster had a good taste.

# %% [markdown]
# _Crispiness_

# %%
categ(cluster_1,"Crispiness")

# %% [markdown]
# Overall this cluster appears to be crunchy performance, where 75% off the recipes were crunchy. Just one recipe wasn´t crunchy.

# %% [markdown]
# _Ingredients_

# %%
sns.set(style='white',font_scale=1.3, rc={'figure.figsize':(20,20)})
ax=cluster_1.hist(bins=20,color='red' )

# %% [markdown]
# This cluster appears to had be made mainly with "farinha de grão de bico" and "farinha de arroz".

# %% [markdown]
# Overall: This recipe appear´s to be one of the best one. It has a good taste, good priting performance and a good taste.

# %% [markdown]
# __Cluster 2__

# %%
cluster_2 = df_AgglomerativeC[df_AgglomerativeC["Cluster"]==2]

# %%
cluster_2.shape
# Out:
# (7, 31)

# %% [markdown]
# We have 7 recipes belonging to the cluster 7.

# %% [markdown]
# _Priting Performance_

# %%
categ(cluster_2,"Priting")

# %% [markdown]
# Overall this cluster appears to have a really bad priting performance, where 100% off the recipes had a bad priting performance.

# %% [markdown]
# _Taste_

# %%
categ(cluster_2,"Taste")

# %% [markdown]
# This cluster appears to have a really bad priting performance, where 100% off the recipes had a bad priting performance.

# %% [markdown]
# _Crispiness_

# %%
categ(cluster_0,"Crispiness")

# %% [markdown]
# The crispiness off this cluster wasn´t the best good, where 87% of the recipes had a bad crispiness.

# %% [markdown]
# _Ingredients_

# %%
sns.set(style='white',font_scale=1.3, rc={'figure.figsize':(20,20)})
ax=cluster_2.hist(bins=20,color='red' )

# %% [markdown]
# This cluster appears to had be made mainly with "farinha de trigo" and "farinha de trigo sarraceno".

# %% [markdown]
# Overall this cluster had the worsts recipes.

# %% [markdown]
# # Conclusions

# %% [markdown]
# In order ro identify which recipe has the best quality and the highest chance to win. It was conducted a descriptive analise and a cluster machine model to determine which product is the best.

# %% [markdown]
# After conducting a correlation analysis using a heatmap, the following conclusions were drawn:
#
# Raw dough texture is strongly correlated with crispiness (0.61), dehydration time (min) (0.64), and goma guar (0.61).
# Printing does not show a strong correlation with any of the variables.
# Taste has a strong positive correlation with farinha de arroz (0.75), farinha de trigo sarraceno (0.63), and farinha de trigo (0.83).
# Crispiness has a strong positive correlation with the texture of raw dough (0.61).
# However, it's important to note that caution should be exercised when interpreting these conclusions, as the dataset is small, imbalanced, and many of the variables do not follow a normal distribution. Additionally, most of the variables have constant values, which may affect the reliability of the observed correlations. Therefore, these conclusions may not be entirely reliable or generalizable to other contexts.

# %% [markdown]
#  A descriptive analysis revealed that only 18% of our formulations had a desirable raw dough texture, while the majority (73%) had a fluid texture. Additionally, only 32% demonstrated good printing performance. In terms of flavor, the majority (76%) had a desirable flavor. And lastly, only 18% were found to be crunchy

# %% [markdown]
# To determine the best formulation, a cluster analysis was conducted. The elbow method and dendrogram method were used, resulting in the identification of three clusters within the data. The dendogram above in illustrates these clusters

# %%
import scipy.cluster.hierarchy as sch
from matplotlib import pyplot
pyplot.figure(figsize=(12, 5))
dendrogram = sch.dendrogram(sch.linkage(df3, method = 'ward'))
plt.title('Dendrogram')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# By applying K-means and hierarchical clustering techniques, we were able to generate clusters that group together formulations with similar ingredients and characteristics of the final product. This means that recipes within the same cluster share common attributes in terms of the ingredients used and the resulting qualities of the product. These clusters help us identify patterns and understand which combination of ingredients and their quantities lead to specific characteristics in the final product. Analyzing the formulations within each cluster provides valuable information for optimizing formulations and achieving desired product outcomes. Furthermore, based on the cluster analysis, we have identified the best 4 formulations that achieve the desirable product outcomes.
# Finally, we concluded that the best formulation consisted in a mixture of three flours: chickpea, chestnut and rice flour, two different hydrocolloids: psyllium husk and HPMC and that the perfect percentage of water and olive oil for our product is 34,5% and 4,1%, respectively

# %%
df_AgglomerativeC[df_AgglomerativeC["Cluster"]==1]
# Out:
#       Farinha de Grão de Bico  Farinha de trigo  Farinha de trigo serraceno  \
# Id
# GB 1                     24.0               0.0                         0.0
# 1FG                      27.0               0.0                         0.0
# 2FG                      22.0               0.0                         0.0
# 3FG                      28.0               0.0                         0.0
#
#       Farinha de castanha  Farinha de arroz  Farinha de Alfarroba  \
# Id
# GB 1                  0.0              22.0                   0.0
# 1FG                   0.0              16.0                   0.0
# 2FG                   3.0              21.0                   0.0
# 3FG                   0.0              13.0                   0.0
#
#       Farinha de maça  Manteiga sem sal  açúcar  sal  ...  pshysillium  \
# Id                                                    ...
# GB 1              0.0               0.0    11.0  1.0  ...          2.0
# ...

# %% [markdown]
# As we can see the cluster "high quality"  are the recipes with "Farinha de Grão de Bico".
